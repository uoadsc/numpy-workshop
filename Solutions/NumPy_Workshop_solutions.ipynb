# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:green; font-style:bold"><br>Jupyter Notebooks</p>

# %% [markdown]
# <p style="font-family: Arial; font-size:4.75em;color:purple; font-style:bold"><br>
# Data ANALYSIS USING NumPy</p><br>

# %% [markdown]
# Import numpy into the notebook

# %%
import numpy as np

# %% [markdown]
# To display NumPy's built-in documentation

# %%
np?

# %% [markdown]
# To display all the contents of the numpy namespace

# %%
# type np and then press shift-tab simultaneously
np

# %% [markdown]
# Create python array and NumPy array

# %%
# Python array in the form of lists
a=[1,2,3,4,5,6,7]

# NumPy array
A=np.array([1,2,3,4,5,6,7])

# %% [markdown]
# Print python and NumPy arrays

# %%
print(a)
print()
print(A)

# %% [markdown]
# What is the difference?

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:	#4169E1; font-style:bold"><br>NumPy Standard Data Types</p><br>
# NumPy is constrained to arrays that all contain the same type.

# %%
np.array([3.14, 4, 2, 5])

# %%
np.array([3.14, 4, 2,"5"])

# %%
np.array([3.14, 4, 2,"5"], dtype='float32')

# %%
np.array([3.14, 4, 2, 5], dtype='int')

# %%
# Can also use associated NumPy object
np.array([10, 10, 10], dtype=np.int16)

# %% [raw]
# # Data type	Description
# bool_	    Boolean (True or False) stored as a byte
# int_	    Default integer type (same as C long; normally either int64 or int32)
# intc	    Identical to C int (normally int32 or int64)
# intp	    Integer used for indexing (same as C ssize_t; normally either int32 or int64)
# int8	    Byte (-128 to 127)
# int16	    Integer (-32768 to 32767)
# int32	    Integer (-2147483648 to 2147483647)
# int64	    Integer (-9223372036854775808 to 9223372036854775807)
# uint8	    Unsigned integer (0 to 255)
# uint16	    Unsigned integer (0 to 65535)
# uint32	    Unsigned integer (0 to 4294967295)
# uint64	    Unsigned integer (0 to 18446744073709551615)
# float_	    Shorthand for float64.
# float16   	Half precision float: sign bit, 5 bits exponent, 10 bits mantissa
# float32 	Single precision float: sign bit, 8 bits exponent, 23 bits mantissa
# float64	    Double precision float: sign bit, 11 bits exponent, 52 bits mantissa
# complex_	Shorthand for complex128.
# complex64	Complex number, represented by two 32-bit floats
# complex128	Complex number, represented by two 64-bit floats

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:#4169E1; font-style:bold"><br>NumPy Array Creation Methods</p><br>

# %%
# Create a 1D integer array filled with zeros of length-15
np.zeros(15, dtype=int)

# %%
# Create a 4x9 floating-point array filled with ones
np.ones((4, 9), dtype=float)

# %%
# Create a 3x5 array filled with 9.81
np.full((3, 5), 9.81)

# %%
# Create a 5x5 array of uniformly distributed
# random values between 0 and 1
np.random.random((5, 5))

# %%
# Create a 3x5 array of normally distributed random values
# with mean 0 and standard deviation 1
np.random.normal(0, 1, (3, 5))

# %%
# Create a 4x4 array of random integers in the interval [0, 20)
np.random.randint(0, 20, (4, 4))

# %%
# Create an array of ten values evenly spaced between 0 and 5
np.linspace(0, 5, 10)

# %%
# Create an array filled with a linear sequence
# Starting at 5, ending at 60, stepping by 2
np.arange(5, 60, 2)

# %%
# Built-in documentation
np.arange

# %%
# Create a 7x7 identity matrix
np.eye(3)

# %%
# Create an uninitialized array of three integers
# The values will be whatever happens to already exist at that memory location
np.empty(8)

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:#4169E1; font-style:bold"><br>Using NumPy to Read in files</p><br>

# %%
# load dataset
cars_data = np.loadtxt("cars.csv", delimiter=",",skiprows=1,usecols=[1,2,3,4,5,6,7,8,9])

# %%
# print dataset
print(cars_data)

# %%
# use the shape property of NumPy arrays to check the number of rows and number of columns
cars_data.shape

# %%
# use of np.genfromtxt
cars1_data=np.genfromtxt("cars.csv",delimiter=",",usecols=[1,2,3,4,5,6,7,8,9])
print(cars1_data)

# skip header
cars1_data=np.genfromtxt("cars.csv",delimiter=",",usecols=[1,2,3,4,5,6,7,8,9],skip_header=1)
print(cars1_data)

# %%
# unpack parameter
a,b,c,d,e,f,g,h,i=np.genfromtxt("cars.csv",delimiter=",",usecols=[1,2,3,4,5,6,7,8,9],skip_header=1,unpack=True)
print(a)
print()
print(b)

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:#4169E1; font-style:bold"><br>INDEXING and SLICING: Heart of NumPy</p><br>

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>Indexing NumPy arrays</p><br>

# %%
# To select individual element
cars_data[0,2]

# %%
# values can be modified
cars_data[0,2]=180
print(cars_data)

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>Slicing NumPy Arrays</p><br>

# %% [markdown]
# data[start:stop:step]
#
# DEFAULT VALUES (if unspecified):
#
# start=0
#
# stop=size of dimension
#
# step=1

# %%
# first three rows
cars_data[:3]

# %%
# first three rows and 3 columns
cars_data[:3,:3]

# %%
# first three rows and every other columns
cars_data[:3,::2]

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>Boolean Indexing</p><br>

# %%
# save the header of the dataset in a numpy array named as "cars_data_header"
cars_data_header = np.loadtxt("cars.csv", delimiter=",",max_rows=1,dtype='str',usecols=[1,2,3,4,5,6,7])
# print header
print(cars_data_header)

# %%
# Create a numpy array named as "horsepower_slice" and save the horsepower values from cars dataset in it
horsepower_slice=cars_data[:,3]
# print horsepower_slice
print(horsepower_slice)

# %%
# Create a filter which will be boolean values for whether each element meet a specific condition
# Create a fiter for horsepower values greater than 140
filter=(horsepower_slice>140)

# %%
# the filter is of the same size and array of the original ndarray and for each element it has either true or false
# print shape of filter
filter.shape

# %%
# print shape of original array
horsepower_slice.shape

# %%
# print filter
filter

# %%
# use the filter as indices to the larger array asking for those values for which the filter is true
# Create a numpy array "cars_names" and store in it the names of the cars from the cars dataset using load.txt
cars_names = np.loadtxt("cars.csv", delimiter=",",dtype='str',usecols=[0],skiprows=1)
# print cars_names
print(cars_names)

# %%
# Apply filter to print all the car names with horsepower greater than 140
print(cars_names[filter])

# %%
# All the above steps can be performed in one step
print(cars_names[horsepower_slice>140])

# %%
# Apply filter for range of values
# Select car names with horsepower between 140 and 150 (both inclusive)
print(cars_names[(horsepower_slice>=140) & (horsepower_slice<=150)])

# %%
# Most USEFUL: change elements in the array by applying a similar logic filter
# Change the car names to "GOLD", which have horsepower between 140 and 150 (both inclusive)
cars_names[(horsepower_slice>140) & (horsepower_slice<=150)] ="GOLD"

# %%
print(cars_names)

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:#4169E1; font-style:bold"><br>Exploring NumPy's Functions</p><br>

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>Creating copies of Arrays</p><br>

# %%
# Select name of cars in the dataset
cars_names = np.loadtxt("cars.csv", delimiter=",",dtype='str',usecols=[0],skiprows=1)

# %%
# Copy numpy array
cars_names_copy=cars_names.copy()

# %%
# Apply filter
cars_names_copy[(horsepower_slice>140) & (horsepower_slice<=150)] ="GOLD"

# %%
# print copied and original array
print(cars_names_copy)
print()
print(cars_names)

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>BASIC STATISTICAL OPERATORS</p><br>

# %%
# compute the mean
print(horsepower_slice.mean())

# %%
# compute the means by column
print(cars_data.mean(axis=0)) 

# compute the means by row
print(cars_data[:8].mean(axis=1))

# %%
# sum all the elements
print(horsepower_slice.sum())

# %%
# Standard deviation
print(np.std(cars_data,axis=0))

# %%
# Variance
print(np.var(cars_data,axis=0))

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>SORTING</p><br>

# %%
cars_data = np.loadtxt("cars.csv", delimiter=",",skiprows=1,usecols=[1,2,3,4,5,6,7,8,9])
horsepower_slice=cars_data[:,3]
print(horsepower_slice)

# %%
# inplace sorting
horsepower_slice.sort()
print(horsepower_slice)

# %%
# Create copy and sort
cars_data = np.loadtxt("cars.csv", delimiter=",",skiprows=1,usecols=[1,2,3,4,5,6,7,8,9])
horsepower_slice=cars_data[:,3]
horsepower_slice_copy=horsepower_slice.copy()
horsepower_slice_copy.sort()
print(horsepower_slice_copy)
print()
print(horsepower_slice)

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>ARITHMETIC OPERATIONS</p><br>

# %%
x=np.array([[351,128],[111,777]], dtype=np.int)
y=np.array([[400.8,261],[35.9,555]], dtype=np.float64)

# %%
print(x)
print()
print(y)

# %%
# add
print(x + y) # either use + sign
print()
print(np.add(x,y)) # or numpy function "add"

# %%
# subtract
print(x - y) 
print()
print(np.subtract(x,y))

# %%
# multiply
print(x * y) 
print()
print(np.multiply(x,y))

# %%
# divide
print(x / y) 
print()
print(np.divide(x,y))

# %%
# square root
print(np.sqrt(y))

# %%
# exponent e ** x
print(np.exp(y))

# %%
# power 
print(np.power(y,3))

# %%
# modulus
print(np.mod(x,5))

# %%
# logarithms
print(np.log(x))
print()
print(np.log2(x))
print()
print(np.log10(x))

# %%
# Trigonometric
theta = np.linspace(0, np.pi, 3)

print("theta      = ", theta)
print("sin(theta) = ", np.sin(theta))
print("cos(theta) = ", np.cos(theta))
print("tan(theta) = ", np.tan(theta))

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:#4169E1; font-style:bold"><br>Speed Comparison : ndarrays vs lists</p><br>

# %%
size=1000000
# create the ndarray with values 0,1,2...,size-1
s_nd_array = np.arange(size)

# %%
# create the list with values 0,1,2...,size-1
s_list = list(range(size))

# %%
# %timeit s_nd_array.sum()
# Out:
# 965 µs ± 66.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit sum(s_list)
# Out:
# 9.68 ms ± 388 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# <p style="font-family: Arial;font-size:3em;color:#4169E1; font-style:bold"><br>IMAGE DATA ANALYSIS using NumPy</p><br>

# %%
# Loading the libraries we need
import numpy as np
import imageio
import matplotlib.pyplot as plt

# %%
# Creating an array from image file
image_data = imageio.imread('galaxy_nasa.jpg')

# %%
# See the image
plt.figure(figsize=(15,15))
plt.imshow(image_data)

# %%
# Image data shape
image_data.shape
# Out:
# (768, 1024, 3)

# %%
# print image data
print(image_data)
# Out:
# [[[ 60   0  32]
#   [ 60   0  30]
#   [ 60   0  28]
#   ...
#   [ 19   1   1]
#   [ 18   0   0]
#   [ 18   0   0]]
#
#  [[ 60   0  30]
#   [ 61   0  31]
#   [ 62   2  28]
#   ...
#   [ 18   0   0]
#   [ 18   0   0]
#   [ 17   0   0]]
#
#  [[ 59   0  27]
#   [ 61   1  29]
#   [ 63   3  29]
#   ...
#   [ 17   0   0]
#   [ 17   0   0]
#   [ 17   0   0]]
#
#  ...
#
#  [[ 26  48  72]
#   [ 24  48  74]
#   [ 20  46  73]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[ 37  36  96]
#   [ 36  35  93]
#   [ 34  33  90]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[ 43  28 111]
#   [ 44  27 107]
#   [ 42  24  98]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]]

# %% [markdown]
# <ul>
# <li><p style="font-family: Arial; font-size:1.75em;color:red; font-style:bold">
# RED pixel indicates Altitude</p>
# <li><p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold">
# BLUE pixel indicates Aspect
# </p>
# <li><p style="font-family: Arial; font-size:1.75em;color:green; font-style:bold">
# GREEN pixel indicates Slope
# </p>
# </ul>
# <br>

# %%
# Image data size
image_data.size
# Out:
# 2359296

# %%
# Min and Max values
image_data.min(), image_data.max()
# Out:
# (0, 255)

# %%
# mean pixel value
image_data.mean()
# Out:
# 40.70907084147135

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>Changing Colors in a Range</p><br>

# %%
# Use slicing to change the blue pixel valu to full intensity for rows 150 to 500
image_data = imageio.imread('galaxy_nasa.jpg')
image_data[150:500, : ,2] = 255
plt.figure(figsize=(10,10))
plt.imshow(image_data)

# %%
# Use slicing to change the rows from 150 to 500 to white colour
image_data = imageio.imread('galaxy_nasa.jpg')

# type here
image_data[150:500, : ,:] = 255

plt.figure(figsize=(10,10))
plt.imshow(image_data)

# %% [markdown]
# <p style="font-family: Arial;font-size:2em;color:#DC143C; font-style:bold"><br>Processing of Red pixels</p><br>

# %%
image_data = imageio.imread('galaxy_nasa.jpg')
red_mask   = image_data[:, : ,0] < 150
image_data[red_mask] = 0
plt.figure(figsize=(10,10))
plt.imshow(image_data)
